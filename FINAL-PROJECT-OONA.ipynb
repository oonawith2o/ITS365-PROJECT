# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Normalization

# %% [markdown]
# ## Import Data from .csv File

# %%
df = pd.read_csv(r'C:\Users\oonak\Documents\PNW\ITS365\ITS365-PROJECT\365finalproject.csv', encoding= 'unicode_escape')

# %%
df
# Out:
#        PlayerID             Player  Age  Games  Minutes  FGM  FGA  3PM  3PA  \
# 0     duartch01       Chris Duarte   24     55     1541  268  621   94  255
# 1     marshna01      Naji Marshall   23     32      700   82  209   29   83
# 2     pritcpa01   Payton Pritchard   23     66     1268  184  418  102  248
# 3     windldy01      Dylan Windler   24     31      513   57  130   26   77
# 4     clarkbr01     Brandon Clarke   23     58     1300  296  479   23   64
# ...         ...                ...  ...    ...      ...  ...  ...  ...  ...
# 1031  kunneke01      Kevin Kunnert   22     64      701  105  215    0    0
# 1032  mcneila01      Larry McNeill   23     54      516  106  220    0    0
# 1033  ratleed01         Ed Ratleff   23     81     1773  254  585    0    0
# 1034  wattssl01        Slick Watts   22     62     1424  198  510    0    0
# 1035  weathni01  Nick Weatherspoon   23     65     1216  199  483    0    0
#
# ...

# %% [markdown]
# ## Normalization of Data

# %%
normalization_layer = tf.keras.layers.Normalization(axis=-1)
normalization_layer.adapt(df.iloc[:,2:-1])

# %%
df_normalized = df.copy()
df_normalized.iloc[:,2:-1] = normalization_layer(df.iloc[:,2:-1])

# %%
df_normalized
# Out:
#        PlayerID             Player       Age     Games   Minutes       FGM  \
# 0     duartch01       Chris Duarte  1.587192 -1.133756  0.033144  0.185949
# 1     marshna01      Naji Marshall  0.800431 -2.971895 -1.208106 -1.071918
# 2     pritcpa01   Payton Pritchard  0.800431 -0.254646 -0.369782 -0.382120
# 3     windldy01      Dylan Windler  1.587192 -3.051814 -1.484103 -1.240986
# 4     clarkbr01     Brandon Clarke  0.800431 -0.893999 -0.322553  0.375305
# ...         ...                ...       ...       ...       ...       ...
# 1031  kunneke01      Kevin Kunnert  0.013671 -0.414484 -1.206630 -0.916375
# 1032  mcneila01      Larry McNeill  0.800431 -1.213675 -1.479675 -0.909612
# 1033  ratleed01         Ed Ratleff  0.800431  0.944140  0.375558  0.091271
# 1034  wattssl01        Slick Watts  0.013671 -0.574323 -0.139539 -0.287442
# 1035  weathni01  Nick Weatherspoon  0.800431 -0.334565 -0.446530 -0.280679
#
# ...

# %% [markdown]
# ## Split Data into Training and Testing Datasets

# %%
train, test = train_test_split(df_normalized, test_size=0.3)

# %%
train
# Out:
#        PlayerID            Player       Age     Games   Minutes       FGM  \
# 778   turpime01     Melvin Turpin  1.587192  0.784302  0.635320  0.828408
# 81    powelno01     Norman Powell  0.013671 -1.613270 -1.171208 -0.970477
# 830   johnsst03     Steve Johnson  1.587192  0.704382  0.328328  1.044815
# 364   willima01       Mo Williams -0.773090 -0.973918 -1.101839 -0.848748
# 593   stithbr01      Bryant Stith  0.013671 -2.412461 -0.964579 -0.787883
# ...         ...               ...       ...       ...       ...       ...
# 776   thompbe01  Bernard Thompson  0.013671 -0.814080 -1.451633 -1.092206
# 618   smithdo03        Doug Smith  0.013671  0.544544  0.278147  0.341492
# 1014  smithph01        Phil Smith  0.013671  0.384706 -0.684154 -0.131899
# 183   johnswe01    Wesley Johnson  0.800431  0.784302  0.812431  0.206237
# 0     duartch01      Chris Duarte  1.587192 -1.133756  0.033144  0.185949
#
#            FGA       3PM       3PA       FTM  ...        PF       PTS  \
# ...

# %%
test
# Out:
#        PlayerID          Player       Age     Games   Minutes       FGM  \
# 619   smithst01     Steve Smith  0.013671 -0.654242  0.424263  0.382068
# 546   bradlsh01   Shawn Bradley -0.773090 -1.613270 -0.197100 -0.267154
# 578   horryro01    Robert Horry  0.013671  0.784302  1.197646  0.557899
# 1033  ratleed01      Ed Ratleff  0.800431  0.944140  0.375558  0.091271
# 588   peelean01  Anthony Peeler  0.800431  0.624463  0.202875  0.382068
# ...         ...             ...       ...       ...       ...       ...
# 95    lavinza01     Zach LaVine -2.346611  0.624463  0.565952  0.307678
# 528    kiddja01     Jason Kidd* -0.773090  0.784302  1.696508  0.605238
# 966   kupchmi01   Mitch Kupchak  0.013671  1.024059 -0.008182  0.679628
# 449   hughela01    Larry Hughes -1.559851 -1.533351 -0.783040 -0.476798
# 474   mcgratr01  Tracy McGrady* -3.133372 -0.414484 -0.501139 -0.415934
#
#            FGA       3PM       3PA       FTM  ...        PF       PTS  \
# ...

# %%
names_train = train.iloc[:,0:2]
x_train = train.iloc[:,2:-1]
y_train = train.iloc[:,-1]

# %%
names_train
# Out:
#        PlayerID            Player
# 778   turpime01     Melvin Turpin
# 81    powelno01     Norman Powell
# 830   johnsst03     Steve Johnson
# 364   willima01       Mo Williams
# 593   stithbr01      Bryant Stith
# ...         ...               ...
# 776   thompbe01  Bernard Thompson
# 618   smithdo03        Doug Smith
# 1014  smithph01        Phil Smith
# 183   johnswe01    Wesley Johnson
# 0     duartch01      Chris Duarte
#
# [725 rows x 2 columns]

# %%
x_train
# Out:
#            Age     Games   Minutes       FGM       FGA       3PM       3PA  \
# 778   1.587192  0.784302  0.635320  0.828408  0.589729 -0.631324 -0.688091
# 81    0.013671 -1.613270 -1.171208 -0.970477 -0.954999  0.448860  0.282368
# 830   1.587192  0.704382  0.328328  1.044815  0.375005 -0.631324 -0.688091
# 364  -0.773090 -0.973918 -1.101839 -0.848748 -0.717841 -0.331273 -0.262834
# 593   0.013671 -2.412461 -0.964579 -0.787883 -0.797962 -0.631324 -0.644475
# ...        ...       ...       ...       ...       ...       ...       ...
# 776   0.013671 -0.814080 -1.451633 -1.092206 -1.009481 -0.631324 -0.600859
# 618   0.013671  0.544544  0.278147  0.341492  0.560885 -0.631324 -0.568147
# 1014  0.013671  0.384706 -0.684154 -0.131899 -0.201864 -0.631324 -0.688091
# 183   0.800431  0.784302  0.812431  0.206237  0.496789  2.459203  2.463177
# 0     1.587192 -1.133756  0.033144  0.185949  0.301294  2.189157  2.092439
#
# ...

# %%
y_train
# Out:
# 778     6.0
# 81      2.4
# 830     4.4
# 364     4.5
# 593     5.2
#        ...
# 776     0.9
# 618     1.0
# 1014    6.3
# 183     0.0
# 0       0.0
# Name: WS_25, Length: 725, dtype: float64

# %%
names_test = test.iloc[:,0:2]
x_test = test.iloc[:,2:-1]
y_test = test.iloc[:,-1]

# %%
names_test
# Out:
#        PlayerID          Player
# 619   smithst01     Steve Smith
# 546   bradlsh01   Shawn Bradley
# 578   horryro01    Robert Horry
# 1033  ratleed01      Ed Ratleff
# 588   peelean01  Anthony Peeler
# ...         ...             ...
# 95    lavinza01     Zach LaVine
# 528    kiddja01     Jason Kidd*
# 966   kupchmi01   Mitch Kupchak
# 449   hughela01    Larry Hughes
# 474   mcgratr01  Tracy McGrady*
#
# [311 rows x 2 columns]

# %%
x_test
# Out:
#            Age     Games   Minutes       FGM       FGA       3PM       3PA  \
# 619   0.013671 -0.654242  0.424263  0.382068  0.407054  0.568881  0.674914
# 546  -0.773090 -1.613270 -0.197100 -0.267154 -0.115334 -0.631324 -0.655379
# 578   0.013671  0.784302  1.197646  0.557899  0.496789 -0.271263 -0.175601
# 1033  0.800431  0.944140  0.375558  0.091271  0.185920 -0.631324 -0.688091
# 588   0.800431  0.624463  0.202875  0.382068  0.342957  0.748912  0.598586
# ...        ...       ...       ...       ...       ...       ...       ...
# 95   -2.346611  0.624463  0.565952  0.307678  0.480765  1.078968  1.132884
# 528  -0.773090  0.784302  1.696508  0.605238  1.057634  1.469034  2.114248
# 966   0.013671  1.024059 -0.008182  0.679628  0.221174 -0.631324 -0.688091
# 449  -1.559851 -1.533351 -0.783040 -0.476798 -0.362105 -0.391283 -0.121081
# 474  -3.133372 -0.414484 -0.501139 -0.415934 -0.413383 -0.211252 -0.241026
#
# ...

# %%
y_test
# Out:
# 619      7.8
# 546      2.9
# 578      4.9
# 1033     4.5
# 588      2.4
#         ...
# 95       5.9
# 528      8.1
# 966      0.2
# 449      3.8
# 474     12.0
# Name: WS_25, Length: 311, dtype: float64

# %%
NUM_FEATURES = x_train.shape[1]

# %% [markdown]
# ## Build DNN

# %%
input_layer = tf.keras.Input(shape=(1, NUM_FEATURES))
