# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

from keras.layers import Normalization, Dense, Dropout
from keras.optimizers import Adam
from keras import regularizers

from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Import Data from .csv File

# %%
df = pd.read_csv(r'365finalproject.csv', encoding= 'unicode_escape')

# %%
df
# Out:
#        PlayerID             Player  Age  Games  Minutes  FGM  FGA  3PM  3PA  \
# 0     duartch01       Chris Duarte   24     55     1541  268  621   94  255
# 1     marshna01      Naji Marshall   23     32      700   82  209   29   83
# 2     pritcpa01   Payton Pritchard   23     66     1268  184  418  102  248
# 3     windldy01      Dylan Windler   24     31      513   57  130   26   77
# 4     clarkbr01     Brandon Clarke   23     58     1300  296  479   23   64
# ...         ...                ...  ...    ...      ...  ...  ...  ...  ...
# 1031  kunneke01      Kevin Kunnert   22     64      701  105  215    0    0
# 1032  mcneila01      Larry McNeill   23     54      516  106  220    0    0
# 1033  ratleed01         Ed Ratleff   23     81     1773  254  585    0    0
# 1034  wattssl01        Slick Watts   22     62     1424  198  510    0    0
# 1035  weathni01  Nick Weatherspoon   23     65     1216  199  483    0    0
#
#       FTM  ...   PF  PTS    FG%    3P%    FT%   MPG   PPG  RPG  APG  WS_25
# 0      90  ...   95  720  0.432  0.369  0.804  28.0  13.1  4.1  2.1    0.0
# 1      53  ...   58  246  0.392  0.349  0.707  21.9   7.7  4.6  2.8    2.5
# 2      40  ...  104  510  0.440  0.411  0.889  19.2   7.7  2.4  1.8    0.6
# 3      21  ...   37  161  0.438  0.338  0.778  16.5   5.2  3.5  1.1    0.8
# 4      85  ...  100  700  0.618  0.359  0.759  22.4  12.1  5.9  1.4    6.3
# ...   ...  ...  ...  ...    ...    ...    ...   ...   ...  ...  ...    ...
# 1031   21  ...  151  231  0.488  0.000  0.636  11.0   3.6  3.4  0.7    4.1
# 1032   99  ...   76  311  0.482  0.000  0.707   9.6   5.8  2.7  0.4    4.3
# 1033  103  ...  182  611  0.434  0.000  0.798  21.9   7.5  3.5  2.2    4.5
# 1034  100  ...  207  496  0.388  0.000  0.645  23.0   8.0  2.9  5.7    3.3
# 1035   96  ...  179  494  0.412  0.000  0.691  18.7   7.6  6.1  0.6    2.4
#
# [1036 rows x 26 columns]

# %%
names_ds = df[["PlayerID", "Player"]]
features_ds_raw = df.loc[:,'Age':'APG']
labels_ds = df[["WS_25"]]

# %%
names_ds
# Out:
#        PlayerID             Player
# 0     duartch01       Chris Duarte
# 1     marshna01      Naji Marshall
# 2     pritcpa01   Payton Pritchard
# 3     windldy01      Dylan Windler
# 4     clarkbr01     Brandon Clarke
# ...         ...                ...
# 1031  kunneke01      Kevin Kunnert
# 1032  mcneila01      Larry McNeill
# 1033  ratleed01         Ed Ratleff
# 1034  wattssl01        Slick Watts
# 1035  weathni01  Nick Weatherspoon
#
# [1036 rows x 2 columns]

# %%
features_ds_raw
# Out:
#       Age  Games  Minutes  FGM  FGA  3PM  3PA  FTM  FTA  ORB  ...  BLK   PF  \
# 0      24     55     1541  268  621   94  255   90  112   41  ...   10   95
# 1      23     32      700   82  209   29   83   53   75   15  ...   10   58
# 2      23     66     1268  184  418  102  248   40   45   33  ...    9  104
# 3      24     31      513   57  130   26   77   21   27   20  ...   12   37
# 4      23     58     1300  296  479   23   64   85  112   92  ...   48  100
# ...   ...    ...      ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1031   22     64      701  105  215    0    0   21   33   83  ...   54  151
# 1032   23     54      516  106  220    0    0   99  140   60  ...    6   76
# 1033   23     81     1773  254  585    0    0  103  129   93  ...   27  182
# 1034   22     62     1424  198  510    0    0  100  155   72  ...   13  207
# 1035   23     65     1216  199  483    0    0   96  139  133  ...   16  179
#
#       PTS    FG%    3P%    FT%   MPG   PPG  RPG  APG
# 0     720  0.432  0.369  0.804  28.0  13.1  4.1  2.1
# 1     246  0.392  0.349  0.707  21.9   7.7  4.6  2.8
# 2     510  0.440  0.411  0.889  19.2   7.7  2.4  1.8
# 3     161  0.438  0.338  0.778  16.5   5.2  3.5  1.1
# 4     700  0.618  0.359  0.759  22.4  12.1  5.9  1.4
# ...   ...    ...    ...    ...   ...   ...  ...  ...
# 1031  231  0.488  0.000  0.636  11.0   3.6  3.4  0.7
# 1032  311  0.482  0.000  0.707   9.6   5.8  2.7  0.4
# 1033  611  0.434  0.000  0.798  21.9   7.5  3.5  2.2
# 1034  496  0.388  0.000  0.645  23.0   8.0  2.9  5.7
# 1035  494  0.412  0.000  0.691  18.7   7.6  6.1  0.6
#
# [1036 rows x 23 columns]

# %%
labels_ds
# Out:
#       WS_25
# 0       0.0
# 1       2.5
# 2       0.6
# 3       0.8
# 4       6.3
# ...     ...
# 1031    4.1
# 1032    4.3
# 1033    4.5
# 1034    3.3
# 1035    2.4
#
# [1036 rows x 1 columns]

# %% [markdown]
# ## Normalization of Data

# %%
normalization_layer = tf.keras.layers.Normalization(axis=-1)
normalization_layer.adapt(features_ds_raw)

# %%
features_ds_normalized = normalization_layer(features_ds_raw)

# %%
features_ds = np.array(features_ds_normalized)

# %%
features_ds
# Out:
# array([[ 1.587192  , -1.133756  ,  0.03314409, ...,  0.9669427 ,
#          0.09333976,  0.11713215],
#        [ 0.8004314 , -2.9718945 , -1.2081058 , ..., -0.21646269,
#          0.3200158 ,  0.55341506],
#        [ 0.8004314 , -0.2546463 , -0.36978245, ..., -0.21646269,
#         -0.6773586 , -0.06984619],
#        ...,
#        [ 0.8004314 ,  0.94413966,  0.37555787, ..., -0.26029247,
#         -0.17867143,  0.17945836],
#        [ 0.01367071, -0.5743225 , -0.13953872, ..., -0.1507179 ,
#         -0.4506826 ,  2.3608725 ],
#        [ 0.8004314 , -0.33456534, -0.44653037, ..., -0.23837757,
#          1.0000439 , -0.81775963]], dtype=float32)

# %% [markdown]
# ## Split Data into Training and Testing Datasets

# %%
n_train, n_test, x_train, x_test, y_train, y_test = train_test_split(names_ds, features_ds, labels_ds, test_size=0.3)

# %%
n_train
# Out:
#       PlayerID                 Player
# 493  marbust01        Stephon Marbury
# 125  beverpa01       Patrick Beverley
# 50   ferreyo01           Yogi Ferrell
# 832  listeal01           Alton Lister
# 716  gattike01         Kenny Gattison
# ..         ...                    ...
# 423  tsakaja01        Jake Tsakalidis
# 182  haywago01         Gordon Hayward
# 105  antetgi01  Giannis Antetokounmpo
# 62   sabondo01       Domantas Sabonis
# 719  johnsbu01           Buck Johnson
#
# [725 rows x 2 columns]

# %%
x_train
# Out:
# array([[-2.3466113 , -0.17472723,  1.1887906 , ...,  1.5586454 ,
#         -0.54135305,  3.6697214 ],
#        [ 1.587192  , -2.2526228 , -1.1889188 , ..., -0.67667586,
#         -0.54135305,  0.61574125],
#        [ 0.8004314 , -1.8530276 , -0.47457287, ...,  0.28758037,
#         -0.6773586 ,  1.1143502 ],
#        ...,
#        [-2.3466113 ,  0.62446344,  0.5585721 , ..., -0.41369683,
#          0.22934547, -0.00752005],
#        [-1.5598506 ,  0.94413966,  0.16745295, ..., -0.61093104,
#         -0.13333626, -0.56845516],
#        [ 0.8004314 , -0.73416066, -1.4737717 , ..., -1.0711442 ,
#         -1.0853755 , -0.75543356]], dtype=float32)

# %%
y_train
# Out:
#      WS_25
# 493    9.6
# 125    4.2
# 50     1.9
# 832    4.0
# 716    1.5
# ..     ...
# 423    0.6
# 182    8.9
# 105   11.1
# 62     7.1
# 719    3.6
#
# [725 rows x 1 columns]

# %%
n_test
# Out:
#        PlayerID           Player
# 950   averibi01     Bird Averitt
# 328   nelsoja01    Jameer Nelson
# 775   stockjo01   John Stockton*
# 582   macledo01      Don MacLean
# 880   vandeki01  Kiki Vandeweghe
# ...         ...              ...
# 233     leeco01     Courtney Lee
# 508   garneke01   Kevin Garnett*
# 726   sallejo01      John Salley
# 1014  smithph01       Phil Smith
# 471   jacksbo01    Bobby Jackson
#
# [311 rows x 2 columns]

# %%
x_test
# Out:
# array([[ 1.587192  ,  0.4646253 , -0.5646041 , ..., -0.1726328 ,
#         -1.3120515 , -0.06984619],
#        [ 0.01367071,  0.7843015 ,  0.13793452, ...,  0.00268645,
#         -0.6773586 ,  0.6780673 ],
#        [ 0.01367071,  1.0240587 , -0.0421279 , ..., -0.67667586,
#         -1.176046  ,  1.9869158 ],
#        ...,
#        [ 0.01367071,  1.0240587 , -0.08197778, ..., -0.7424205 ,
#         -0.13333626, -0.75543356],
#        [ 0.01367071,  0.38470623, -0.68415374, ..., -0.21646269,
#         -0.90403473, -0.06984619],
#        [ 1.587192  , -0.09480816,  0.77258074, ...,  0.63821906,
#          0.22934547,  1.7376113 ]], dtype=float32)

# %%
y_test
# Out:
#       WS_25
# 950    -0.7
# 328     5.6
# 775    14.1
# 582     1.1
# 880    10.3
# ...     ...
# 233     2.7
# 508    12.8
# 726     6.1
# 1014    6.3
# 471     1.2
#
# [311 rows x 1 columns]

# %%
NUM_FEATURES = x_train.shape[1]
print(NUM_FEATURES)
# Out:
# 23

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Histogram

# %%
sb.histplot(data=features_ds_raw)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Boxplot

# %%
sb.boxplot(data=features_ds_raw)
# Out:
# <Axes: >

# %% [markdown]
# ## Correlation Matrix

# %%
C_mat = features_ds_raw.corr()
C_mat
# Out:
#               Age     Games   Minutes       FGM       FGA       3PM       3PA  \
# Age      1.000000 -0.062249 -0.152536 -0.123242 -0.140463 -0.141146 -0.156508
# Games   -0.062249  1.000000  0.674487  0.555424  0.554319  0.107752  0.113800
# Minutes -0.152536  0.674487  1.000000  0.900375  0.908371  0.286406  0.303400
# FGM     -0.123242  0.555424  0.900375  1.000000  0.983146  0.190205  0.202158
# FGA     -0.140463  0.554319  0.908371  0.983146  1.000000  0.282626  0.302943
# 3PM     -0.141146  0.107752  0.286406  0.190205  0.282626  1.000000  0.989325
# 3PA     -0.156508  0.113800  0.303400  0.202158  0.302943  0.989325  1.000000
# FTM     -0.141720  0.490012  0.790802  0.851666  0.828008  0.064099  0.082346
# FTA     -0.147762  0.495012  0.786518  0.846672  0.813773  0.009219  0.027176
# ORB     -0.082837  0.431727  0.577279  0.590782  0.514228 -0.275923 -0.281112
# 3PM     -0.367369  0.603155  0.350239  0.319209  0.268974 -0.169194  0.283505
# 3PA     -0.408583  0.601283  0.353754  0.337909  0.281936 -0.173032  0.315467
# FTM      0.195483 -0.046515  0.218505  0.742059  0.862918  0.583954  0.396505
# FTA      0.244001 -0.098276  0.074302  0.733806  0.846603  0.645331  0.352612
# ORB      0.444170 -0.329255 -0.222753  0.501866  0.513447  0.899424 -0.084393
# TRB      0.387828 -0.237010 -0.146872  0.621759  0.604043  0.957791  0.022479
# AST     -0.165241  0.172613  0.286275  0.599178  0.505553  0.010220  0.972715
# STL     -0.042843  0.076672  0.170217  0.672685  0.586566  0.230827  0.707317
# BLK      0.366877 -0.248060 -0.260167  0.331145  0.316250  0.673984 -0.157144
# PF       0.297701 -0.213778 -0.056811  0.615297  0.567395  0.636986  0.215529
# PTS      0.164210  0.057563  0.231005  0.859799  0.962311  0.573096  0.468260
# FG%      1.000000 -0.373666 -0.293713  0.063670  0.149284  0.416764 -0.212664
# 3P%     -0.373666  1.000000  0.322740  0.118110  0.084334 -0.265180  0.202665
# FT%     -0.293713  0.322740  1.000000  0.188330  0.245091 -0.203092  0.303531
# MPG      0.063670  0.118110  0.188330  1.000000  0.883925  0.596452  0.584392
# PPG      0.149284  0.084334  0.245091  0.883925  1.000000  0.576911  0.482744
# RPG      0.416764 -0.265180 -0.203092  0.596452  0.576911  1.000000 -0.027565
# APG     -0.212664  0.202665  0.303531  0.584392  0.482744 -0.027565  1.000000
#
# [23 rows x 23 columns]

# %%
fig = plt.figure(figsize = (15,15))
sb.heatmap(C_mat, vmax=.8, square=True)
plt.show()

# %% [markdown]
# ## Filter Methods

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# ## K-Means Clustering

# %% [markdown]
# ## DNN Architecture

# %%
input_layer = tf.keras.layers.Input(shape=(NUM_FEATURES))

x = tf.keras.layers.Dense(units=1024, activation='relu', kernel_regularizer=regularizers.l2(0.01))(input_layer)
x = tf.keras.layers.Dropout(0.25)(x)
x = tf.keras.layers.Dense(units=512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.25)(x)
x = tf.keras.layers.Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.25)(x)
x = tf.keras.layers.Dense(units=128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.25)(x)

output_layer = tf.keras.layers.Dense(units=1, activation='linear')(x)

Model = tf.keras.Model(input_layer, output_layer)

# %%
Model.summary()

# %% [markdown]
# ## Training Process

# %%
callback = tf.keras.callbacks.EarlyStopping (
    monitor = 'mean_absolute_error',
    patience = 5,
    restore_best_weights = True
)

# %%
Model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.005), metrics=['mean_absolute_error'])

# %%
Model.load_weights("Model-02-004.h5")

# %%
history = Model.fit (
    x_train, 
    y_train,
    validation_data = (x_test, y_test),
    epochs = 50,
    callbacks = [callback]
)

# %%
Model.evaluate(x_test, y_test)

# %%
Model.save("ModelCNN.h5")

# %% [markdown]
# # Result Interpretation & Evaluation

# %%
plt.plot(history.history['mean_absolute_error']) 
plt.plot(history.history['val_mean_absolute_error']) 
plt.legend(['Training Set', 'Testing Set'], loc='upper left')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('Model MAE')
plt.show()

# %%
preds = Model.predict(x_test)

# %% [markdown]
# ## Correlation Coefficient

# %%
r2 = r2_score(y_test, preds)

# %%
r2
