# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from keras.layers import Normalization, Dense
from keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Import Data from .csv File

# %%
df = pd.read_csv(r'C:\Users\oonak\Documents\PNW\ITS365\ITS365-PROJECT\365finalproject.csv', encoding= 'unicode_escape')

# %%
df
# Out:
#        PlayerID             Player  Age  Games  Minutes  FGM  FGA  3PM  3PA  \
# 0     duartch01       Chris Duarte   24     55     1541  268  621   94  255
# 1     marshna01      Naji Marshall   23     32      700   82  209   29   83
# 2     pritcpa01   Payton Pritchard   23     66     1268  184  418  102  248
# 3     windldy01      Dylan Windler   24     31      513   57  130   26   77
# 4     clarkbr01     Brandon Clarke   23     58     1300  296  479   23   64
# ...         ...                ...  ...    ...      ...  ...  ...  ...  ...
# 1031  kunneke01      Kevin Kunnert   22     64      701  105  215    0    0
# 1032  mcneila01      Larry McNeill   23     54      516  106  220    0    0
# 1033  ratleed01         Ed Ratleff   23     81     1773  254  585    0    0
# 1034  wattssl01        Slick Watts   22     62     1424  198  510    0    0
# 1035  weathni01  Nick Weatherspoon   23     65     1216  199  483    0    0
#
#       FTM  ...   PF  PTS    FG%    3P%    FT%   MPG   PPG  RPG  APG  WS_25
# 0      90  ...   95  720  0.432  0.369  0.804  28.0  13.1  4.1  2.1    0.0
# 1      53  ...   58  246  0.392  0.349  0.707  21.9   7.7  4.6  2.8    2.5
# 2      40  ...  104  510  0.440  0.411  0.889  19.2   7.7  2.4  1.8    0.6
# 3      21  ...   37  161  0.438  0.338  0.778  16.5   5.2  3.5  1.1    0.8
# 4      85  ...  100  700  0.618  0.359  0.759  22.4  12.1  5.9  1.4    6.3
# ...   ...  ...  ...  ...    ...    ...    ...   ...   ...  ...  ...    ...
# 1031   21  ...  151  231  0.488  0.000  0.636  11.0   3.6  3.4  0.7    4.1
# 1032   99  ...   76  311  0.482  0.000  0.707   9.6   5.8  2.7  0.4    4.3
# 1033  103  ...  182  611  0.434  0.000  0.798  21.9   7.5  3.5  2.2    4.5
# 1034  100  ...  207  496  0.388  0.000  0.645  23.0   8.0  2.9  5.7    3.3
# 1035   96  ...  179  494  0.412  0.000  0.691  18.7   7.6  6.1  0.6    2.4
#
# [1036 rows x 26 columns]

# %%
names_ds = df[["PlayerID", "Player"]]
features_ds_raw = df.loc[:,'Age':'APG']
labels_ds = df[["WS_25"]]

# %%
names_ds
# Out:
#        PlayerID             Player
# 0     duartch01       Chris Duarte
# 1     marshna01      Naji Marshall
# 2     pritcpa01   Payton Pritchard
# 3     windldy01      Dylan Windler
# 4     clarkbr01     Brandon Clarke
# ...         ...                ...
# 1031  kunneke01      Kevin Kunnert
# 1032  mcneila01      Larry McNeill
# 1033  ratleed01         Ed Ratleff
# 1034  wattssl01        Slick Watts
# 1035  weathni01  Nick Weatherspoon
#
# [1036 rows x 2 columns]

# %%
features_ds_raw
# Out:
#       Age  Games  Minutes  FGM  FGA  3PM  3PA  FTM  FTA  ORB  ...  BLK   PF  \
# 0      24     55     1541  268  621   94  255   90  112   41  ...   10   95
# 1      23     32      700   82  209   29   83   53   75   15  ...   10   58
# 2      23     66     1268  184  418  102  248   40   45   33  ...    9  104
# 3      24     31      513   57  130   26   77   21   27   20  ...   12   37
# 4      23     58     1300  296  479   23   64   85  112   92  ...   48  100
# ...   ...    ...      ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1031   22     64      701  105  215    0    0   21   33   83  ...   54  151
# 1032   23     54      516  106  220    0    0   99  140   60  ...    6   76
# 1033   23     81     1773  254  585    0    0  103  129   93  ...   27  182
# 1034   22     62     1424  198  510    0    0  100  155   72  ...   13  207
# 1035   23     65     1216  199  483    0    0   96  139  133  ...   16  179
#
#       PTS    FG%    3P%    FT%   MPG   PPG  RPG  APG
# 0     720  0.432  0.369  0.804  28.0  13.1  4.1  2.1
# 1     246  0.392  0.349  0.707  21.9   7.7  4.6  2.8
# 2     510  0.440  0.411  0.889  19.2   7.7  2.4  1.8
# 3     161  0.438  0.338  0.778  16.5   5.2  3.5  1.1
# 4     700  0.618  0.359  0.759  22.4  12.1  5.9  1.4
# ...   ...    ...    ...    ...   ...   ...  ...  ...
# 1031  231  0.488  0.000  0.636  11.0   3.6  3.4  0.7
# 1032  311  0.482  0.000  0.707   9.6   5.8  2.7  0.4
# 1033  611  0.434  0.000  0.798  21.9   7.5  3.5  2.2
# 1034  496  0.388  0.000  0.645  23.0   8.0  2.9  5.7
# 1035  494  0.412  0.000  0.691  18.7   7.6  6.1  0.6
#
# [1036 rows x 23 columns]

# %%
labels_ds
# Out:
#       WS_25
# 0       0.0
# 1       2.5
# 2       0.6
# 3       0.8
# 4       6.3
# ...     ...
# 1031    4.1
# 1032    4.3
# 1033    4.5
# 1034    3.3
# 1035    2.4
#
# [1036 rows x 1 columns]

# %% [markdown]
# ## Normalization of Data

# %%
normalization_layer = tf.keras.layers.Normalization(axis=-1)
normalization_layer.adapt(features_ds)

# %%
features_ds_normalized = normalization_layer(features_ds)

# %%
features_ds = np.array(features_ds_normalized)

# %%
features_ds
# Out:
# array([[ 1.5871913 , -1.1337554 ,  0.03314411, ...,  0.9669427 ,
#          0.0933397 ,  0.11713211],
#        [ 0.8004305 , -2.971894  , -1.2081058 , ..., -0.2164627 ,
#          0.32001573,  0.553415  ],
#        [ 0.8004305 , -0.25464565, -0.36978242, ..., -0.2164627 ,
#         -0.6773587 , -0.06984621],
#        ...,
#        [ 0.8004305 ,  0.94414043,  0.3755579 , ..., -0.2602925 ,
#         -0.1786715 ,  0.17945834],
#        [ 0.01366957, -0.5743219 , -0.1395387 , ..., -0.15071791,
#         -0.45068267,  2.3608723 ],
#        [ 0.8004305 , -0.3345647 , -0.44653034, ..., -0.23837759,
#          1.0000439 , -0.8177595 ]], dtype=float32)

# %% [markdown]
# ## Split Data into Training and Testing Datasets

# %%
n_train, n_test, x_train, x_test, y_train, y_test = train_test_split(names_ds, features_ds, labels_ds, test_size=0.3)

# %%
n_train
# Out:
#       PlayerID             Player
# 151   coleno01        Norris Cole
# 564  rideris01       Isaiah Rider
# 45   bertada01      D?vis Bert?ns
# 88   clarkjo01    Jordan Clarkson
# 842  valenda01  Darnell Valentine
# ..         ...                ...
# 101  stausni01       Nik Stauskas
# 920  theusre01       Reggie Theus
# 215  thornma01    Marcus Thornton
# 909  hardyja01        James Hardy
# 282  rondora01        Rajon Rondo
#
# [725 rows x 2 columns]

# %%
x_train
# Out:
# array([[ 0.8004305 , -0.3345647 , -0.3815898 , ..., -0.41369686,
#         -1.1307108 ,  0.05480606],
#        [ 0.01366957,  0.7843023 ,  1.3230994 , ...,  1.7339647 ,
#          0.04800455,  0.42876267],
#        [ 1.5871913 , -0.17472656, -1.0487063 , ..., -0.91773987,
#         -1.0853755 , -0.75543344],
#        ...,
#        [ 0.01366957,  0.30478787,  0.5216741 , ...,  1.2737515 ,
#         -0.45068267, -0.19449838],
#        [ 0.01366957, -0.0948075 , -0.09230921, ..., -0.43561184,
#          0.32001573, -0.5684551 ],
#        [-1.5598522 ,  0.7043832 ,  0.46116135, ..., -0.5013565 ,
#         -0.08800106,  1.1766762 ]], dtype=float32)

# %%
y_train
# Out:
#      WS_25
# 151    1.2
# 564    5.0
# 45     3.1
# 88     3.0
# 842    5.0
# ..     ...
# 101    1.1
# 920    6.5
# 215    3.2
# 909    2.5
# 282    4.9
#
# [725 rows x 1 columns]

# %%
n_test
# Out:
#       PlayerID           Player
# 386  brownkw01      Kwame Brown
# 477  vanhoke01   Keith Van Horn
# 363   westda01       David West
# 854  cartebu01     Butch Carter
# 677  grantha01     Harvey Grant
# ..         ...              ...
# 486  feickja01      Jamie Feick
# 266  bargnan01  Andrea Bargnani
# 640  scottde01     Dennis Scott
# 503  barrybr01      Brent Barry
# 244  afflaar01    Arron Afflalo
#
# [311 rows x 2 columns]

# %%
x_test
# Out:
# array([[-2.3466132 , -0.9739173 , -1.035423  , ..., -0.91773987,
#         -0.1786715 , -0.69310725],
#        [ 0.01366957, -0.5743219 ,  1.1902665 , ...,  2.4133272 ,
#          1.2267199 , -0.13217226],
#        [ 0.8004305 ,  0.14494973, -0.8686439 , ..., -1.0711442 ,
#          0.13867487, -0.69310725],
#        ...,
#        [ 0.01366957,  1.0240595 ,  1.2065016 , ...,  1.5367304 ,
#         -0.45068267, -0.19449838],
#        [ 1.5871913 ,  0.7843023 ,  0.56004804, ...,  0.30949533,
#         -0.8133644 ,  0.6157412 ],
#        [ 0.01366957,  0.46462604, -0.809607  , ..., -1.0930592 ,
#         -0.94937   , -0.75543344]], dtype=float32)

# %%
y_test
# Out:
#      WS_25
# 386    0.6
# 477    2.8
# 363    7.4
# 854    2.6
# 677    6.7
# ..     ...
# 486    4.8
# 266    2.5
# 640    5.0
# 503    2.1
# 244    6.2
#
# [311 rows x 1 columns]

# %%
NUM_FEATURES = x_train.shape[1]
print(NUM_FEATURES)
# Out:
# 23

# %% [markdown]
# ## Histogram

# %%
histograms = features_ds_raw.hist()
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
C_mat = features_ds_raw.corr()
fig = plt.figure(figsize = (15,15))
sb.heatmap(C_mat, vmax=.8, square=True)
plt.show()

# %% [markdown]
# ## DNN Architecture

# %%
input_layer = tf.keras.layers.Input(shape=(NUM_FEATURES))

x = tf.keras.layers.Dense(units=160, activation='relu')(input_layer)
x = tf.keras.layers.Dense(units=160, activation='relu')(x)
x = tf.keras.layers.Dense(units=160, activation='relu')(x)
x = tf.keras.layers.Dense(units=160, activation='relu')(x)

output_layer = tf.keras.layers.Dense(units=1, activation='linear')(x)

Model = tf.keras.Model(input_layer, output_layer)

# %%
Model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 23)]              0
#
#  dense_20 (Dense)            (None, 160)               3840
#
#  dense_21 (Dense)            (None, 160)               25760
#
#  dense_22 (Dense)            (None, 160)               25760
#
#  dense_23 (Dense)            (None, 160)               25760
#
#  dense_24 (Dense)            (None, 1)                 161
#
# =================================================================
# Total params: 81,281
# Trainable params: 81,281
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training Process

# %%
callback = tf.keras.callbacks.EarlyStopping (
    monitor = 'mean_absolute_error',
    patience = 5,
    restore_best_weights = True
)

# %%
Model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.005), metrics=['mean_absolute_error'])

# %%
history = Model.fit (
    x_train, 
    y_train,
    validation_data = (x_test, y_test),
    epochs = 50,
    callbacks = [callback]
)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 14ms/step - loss: 1.2841 - mean_absolute_error: 1.2841 - val_loss: 2.3890 - val_mean_absolute_error: 2.3890
# Epoch 2/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.2404 - mean_absolute_error: 1.2404 - val_loss: 2.5123 - val_mean_absolute_error: 2.5123
# Epoch 3/50
# 23/23 [==============================] - 0s 10ms/step - loss: 1.2649 - mean_absolute_error: 1.2649 - val_loss: 2.3846 - val_mean_absolute_error: 2.3846
# Epoch 4/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.2538 - mean_absolute_error: 1.2538 - val_loss: 2.4239 - val_mean_absolute_error: 2.4239
# Epoch 5/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.1664 - mean_absolute_error: 1.1664 - val_loss: 2.4486 - val_mean_absolute_error: 2.4486
# Epoch 6/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.1396 - mean_absolute_error: 1.1396 - val_loss: 2.4302 - val_mean_absolute_error: 2.4302
# Epoch 7/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.2959 - mean_absolute_error: 1.2959 - val_loss: 2.4406 - val_mean_absolute_error: 2.4406
# Epoch 8/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.1797 - mean_absolute_error: 1.1797 - val_loss: 2.3966 - val_mean_absolute_error: 2.3966
# Epoch 9/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0793 - mean_absolute_error: 1.0793 - val_loss: 2.4151 - val_mean_absolute_error: 2.4151
# Epoch 10/50
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0404 - mean_absolute_error: 1.0404 - val_loss: 2.4987 - val_mean_absolute_error: 2.4987
# Epoch 11/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0879 - mean_absolute_error: 1.0879 - val_loss: 2.4872 - val_mean_absolute_error: 2.4872
# Epoch 12/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0562 - mean_absolute_error: 1.0562 - val_loss: 2.4886 - val_mean_absolute_error: 2.4886
# Epoch 13/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.0263 - mean_absolute_error: 1.0263 - val_loss: 2.4821 - val_mean_absolute_error: 2.4821
# Epoch 14/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9903 - mean_absolute_error: 0.9903 - val_loss: 2.4407 - val_mean_absolute_error: 2.4407
# Epoch 15/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0727 - mean_absolute_error: 1.0727 - val_loss: 2.3742 - val_mean_absolute_error: 2.3742
# Epoch 16/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0082 - mean_absolute_error: 1.0082 - val_loss: 2.4647 - val_mean_absolute_error: 2.4647
# Epoch 17/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0192 - mean_absolute_error: 1.0192 - val_loss: 2.5313 - val_mean_absolute_error: 2.5313
# Epoch 18/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9391 - mean_absolute_error: 0.9391 - val_loss: 2.5074 - val_mean_absolute_error: 2.5074
# Epoch 19/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.9520 - mean_absolute_error: 0.9520 - val_loss: 2.4808 - val_mean_absolute_error: 2.4808
# Epoch 20/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9940 - mean_absolute_error: 0.9940 - val_loss: 2.4760 - val_mean_absolute_error: 2.4760
# Epoch 21/50
# 23/23 [==============================] - 0s 8ms/step - loss: 0.9673 - mean_absolute_error: 0.9673 - val_loss: 2.4514 - val_mean_absolute_error: 2.4514
# Epoch 22/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.9188 - mean_absolute_error: 0.9188 - val_loss: 2.5018 - val_mean_absolute_error: 2.5018
# Epoch 23/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.9404 - mean_absolute_error: 0.9404 - val_loss: 2.4664 - val_mean_absolute_error: 2.4664
# Epoch 24/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.9039 - mean_absolute_error: 0.9039 - val_loss: 2.5350 - val_mean_absolute_error: 2.5350
# Epoch 25/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.8512 - mean_absolute_error: 0.8512 - val_loss: 2.4651 - val_mean_absolute_error: 2.4651
# Epoch 26/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8575 - mean_absolute_error: 0.8575 - val_loss: 2.4612 - val_mean_absolute_error: 2.4612
# Epoch 27/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8357 - mean_absolute_error: 0.8357 - val_loss: 2.4977 - val_mean_absolute_error: 2.4977
# Epoch 28/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.9459 - mean_absolute_error: 0.9459 - val_loss: 2.4869 - val_mean_absolute_error: 2.4869
# Epoch 29/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9422 - mean_absolute_error: 0.9422 - val_loss: 2.5632 - val_mean_absolute_error: 2.5632
# Epoch 30/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8308 - mean_absolute_error: 0.8308 - val_loss: 2.5490 - val_mean_absolute_error: 2.5490
# Epoch 31/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.8446 - mean_absolute_error: 0.8446 - val_loss: 2.4672 - val_mean_absolute_error: 2.4672
# Epoch 32/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8559 - mean_absolute_error: 0.8559 - val_loss: 2.4332 - val_mean_absolute_error: 2.4332
# Epoch 33/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7547 - mean_absolute_error: 0.7547 - val_loss: 2.5219 - val_mean_absolute_error: 2.5219
# Epoch 34/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7460 - mean_absolute_error: 0.7460 - val_loss: 2.4269 - val_mean_absolute_error: 2.4269
# Epoch 35/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8290 - mean_absolute_error: 0.8290 - val_loss: 2.5130 - val_mean_absolute_error: 2.5130
# Epoch 36/50
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7766 - mean_absolute_error: 0.7766 - val_loss: 2.4380 - val_mean_absolute_error: 2.4380
# Epoch 37/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7650 - mean_absolute_error: 0.7650 - val_loss: 2.4738 - val_mean_absolute_error: 2.4738
# Epoch 38/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7237 - mean_absolute_error: 0.7237 - val_loss: 2.6566 - val_mean_absolute_error: 2.6566
# Epoch 39/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7234 - mean_absolute_error: 0.7234 - val_loss: 2.5258 - val_mean_absolute_error: 2.5258
# Epoch 40/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7288 - mean_absolute_error: 0.7288 - val_loss: 2.5539 - val_mean_absolute_error: 2.5539
# Epoch 41/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7410 - mean_absolute_error: 0.7410 - val_loss: 2.5514 - val_mean_absolute_error: 2.5514
# Epoch 42/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7499 - mean_absolute_error: 0.7499 - val_loss: 2.4755 - val_mean_absolute_error: 2.4755
# Epoch 43/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6916 - mean_absolute_error: 0.6916 - val_loss: 2.5655 - val_mean_absolute_error: 2.5655
# Epoch 44/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6556 - mean_absolute_error: 0.6556 - val_loss: 2.5602 - val_mean_absolute_error: 2.5602
# Epoch 45/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6507 - mean_absolute_error: 0.6507 - val_loss: 2.5364 - val_mean_absolute_error: 2.5364
# Epoch 46/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6634 - mean_absolute_error: 0.6634 - val_loss: 2.5695 - val_mean_absolute_error: 2.5695
# Epoch 47/50
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6236 - mean_absolute_error: 0.6236 - val_loss: 2.6558 - val_mean_absolute_error: 2.6558
# Epoch 48/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6125 - mean_absolute_error: 0.6125 - val_loss: 2.5896 - val_mean_absolute_error: 2.5896
# Epoch 49/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6219 - mean_absolute_error: 0.6219 - val_loss: 2.5123 - val_mean_absolute_error: 2.5123
# Epoch 50/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5866 - mean_absolute_error: 0.5866 - val_loss: 2.5069 - val_mean_absolute_error: 2.5069

# %%
plt.plot(history.history['mean_absolute_error']) 
plt.plot(history.history['val_mean_absolute_error']) 
plt.legend(['Training Set', 'Testing Set'], loc='upper left')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('Model MAE')
plt.show()
